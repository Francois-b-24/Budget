# %%
import streamlit_authenticator as stauth

mot_de_passe_clair = "Francois_king"
hashed_password = stauth.Hasher.hash(mot_de_passe_clair)
print(hashed_password)
# Out:
# $2b$12$s1PpvW.rqip9ABV01/iIn.K1yyIVjy21v4Y9xGs4Q54GERWlCnlyC
